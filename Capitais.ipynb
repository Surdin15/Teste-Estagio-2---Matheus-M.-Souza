# %%
import requests #importar a bibiblioteca "requets"
import json     #importar a bibiblioteca "json"
import pprint   #importar a biblioteca "pprint"
import datetime #importar a biblioteca "datetime"

capitais = requests.get("https://restcountries.com/v3.1/independent?status=true&fields=languages,capital") #atribuir na variavel "capitais" os dados da API
capitais = capitais.json() #os dados da API vão serem transferidos do formato json para o formato de exibição do Python

data_hoje = datetime.date.today()
print ("Encoding: utf-8     Data:",data_hoje) #imprimir o enconding e a data atual
print () #imprime uma linha em branco
pprint.pprint (capitais) # exibir os dados que estão dentro da variável "capitais" de forma organizada
# Out:
# Encoding: utf-8     Data: 2023-03-27
#
# [{'capital': ['Bridgetown'], 'languages': {'eng': 'English'}},
#  {'capital': ['Paramaribo'], 'languages': {'nld': 'Dutch'}},
#  {'capital': ['Windhoek'],
#   'languages': {'afr': 'Afrikaans',
#                 'deu': 'German',
#                 'eng': 'English',
#                 'her': 'Herero',
#                 'hgm': 'Khoekhoe',
#                 'kwn': 'Kwangali',
#                 'loz': 'Lozi',
#                 'ndo': 'Ndonga',
#                 'tsn': 'Tswana'}},
#  {'capital': ['Conakry'], 'languages': {'fra': 'French'}},
#  {'capital': ['Port Vila'],
#   'languages': {'bis': 'Bislama', 'eng': 'English', 'fra': 'French'}},
#  {'capital': ['Apia'], 'languages': {'eng': 'English', 'smo': 'Samoan'}},
#  {'capital': ['Paris'], 'languages': {'fra': 'French'}},
#  {'capital': ['Andorra la Vella'], 'languages': {'cat': 'Catalan'}},
#  {'capital': ['Baku'], 'languages': {'aze': 'Azerbaijani', 'rus': 'Russian'}},
# ...
